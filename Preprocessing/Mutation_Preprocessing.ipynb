# %%
import numpy as np
import pandas as pd
import os
import requests
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %% [markdown]
# Function to fetch CRY1 gene sequence from UCSC API

# %%
def get_CRY1_gene():
    response = requests.get("https://api.genome.ucsc.edu/getData/sequence?genome=hg38;chrom=chr12;start=106991364;end=107093549")
    if response.status_code == 200:
        return response.json().get("dna", "").upper()
    else:
        return None

# %% [markdown]
# One-hot encode sequence and return a 1D array

# %%
def onehotencoder(fasta_sequence, max_length = 102500):
    sequence_array = np.array(list(fasta_sequence))
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(sequence_array)
    onehotencoder = OneHotEncoder(sparse_output=False, dtype = np.float32)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_sequence = onehotencoder.fit_transform(integer_encoded).astype(np.float32)
    if onehot_sequence.shape[0] < max_length:
        pad_size = max_length - onehot_sequence.shape[0]
        padding = np.zeros((pad_size, onehot_sequence.shape[1]))
        onehot_sequence = np.vstack([onehot_sequence, padding])
    else:
        onehot_sequence = onehot_sequence[:max_length, :]
    return(onehot_sequence.flatten())
# Function to add mutation to the CRY1 sequence
def add_mutation(seq, start, end, refnuc, altnuc):
    seq_start = start
    seq_end = end
    if seq[seq_start:seq_end] != refnuc:
        print(f"Mutation mismatch at positions {start}-{end}.")
        return None
    else:
        mutated_seq = seq[:seq_start] + altnuc + seq[seq_end:]
        return mutated_seq

# %% [markdown]
# Process the mutation CSV and apply mutations to the CRY1 sequence

# %%
def process_mutations(csv_path, cry1_seq, output_path):
    df = pd.read_csv(csv_path, usecols=['chromEnd', 'ref', 'alt', 'AF', 'genes', 'variation_type', '_displayName'])
    df = df[df["variation_type"].str.contains("intron_variant", na=False, case=False)]

    # Initialize existing data for appending
    if os.path.exists(output_path):
        existing_data = np.load(output_path, allow_pickle=True)["arr_0"].tolist()
    else:
        existing_data = []

    # Process each row in the CSV
    seq_count = 0
    batch = 500
    rows_save = []
    max_seq_count = 5000
    for index, row in df.iterrows():
        if seq_count >= max_seq_count:
            print("Reached maximum sequence count.")
            break
        gnomAD_ID = row["_displayName"]
        refnuc = str(row["ref"]) if pd.notna(row["ref"]) else ""
        start = row["chromEnd"] - 106991364 - len(row["ref"])
        end = row["chromEnd"] - 106991364
        altnuc = str(row["alt"]) if pd.notna(row["alt"]) else ""

        # Add mutation to the sequence
        mutated_seq = add_mutation(cry1_seq, start, end, refnuc, altnuc)
        print(f"{seq_count}: Processed mutation {gnomAD_ID} at positions {start}-{end}.")
        if mutated_seq:
            encoded_seq = onehotencoder(mutated_seq)
            seq_count += 1
            rows_save.append(encoded_seq)
            if len(rows_save) >= batch:
                existing_data.extend(rows_save)
                np.savez_compressed(output_path, arr_0=np.array(existing_data))
                rows_save = []

    if rows_save:
        existing_data.extend(rows_save)
        np.savez_compressed(output_path, arr_0=np.array(existing_data))
    print(f"Processed {seq_count} mutated sequences and saved to {output_path}.")

# %% [markdown]
# Path to CSV file with mutations and output path

# %%
csv_file = "cry1realvariations (1).csv"
output_file = "E:\\datasets\\processeddata\\MUTATION_DATA_TRAINING_5000_2.npz"

# %% [markdown]
# Fetch CRY1 sequence and process mutations

# %%
cry1_seq = get_CRY1_gene()
if cry1_seq:
    process_mutations(csv_file, cry1_seq, output_file)
else:
    print("Failed to fetch CRY1 gene sequence.")
# Out:
# 123: Processed mutation chr12-106992013-G-A at positions 648-649.
# 124: Processed mutation chr12-106992014-G-A at positions 649-650.
# 125: Processed mutation chr12-106992015-G-A at positions 650-651.
# 126: Processed mutation chr12-106992017-G-A at positions 652-653.
# 127: Processed mutation chr12-106992017-G-GA at positions 652-653.
# 128: Processed mutation chr12-106992018-A-C at positions 653-654.
# 129: Processed mutation chr12-106992018-A-G at positions 653-654.
# 130: Processed mutation chr12-106992017-GA-G at positions 652-654.
# 131: Processed mutation chr12-106992031-G-A at positions 666-667.
# 132: Processed mutation chr12-106992037-C-G at positions 672-673.
# 133: Processed mutation chr12-106992042-T-G at positions 677-678.
# 134: Processed mutation chr12-106992042-T-C at positions 677-678.
# 135: Processed mutation chr12-106992045-C-A at positions 680-681.
# 136: Processed mutation chr12-106992045-C-T at positions 680-681.
# 137: Processed mutation chr12-106992051-A-G at positions 686-687.
# 138: Processed mutation chr12-106992066-T-C at positions 701-702.
# 139: Processed mutation chr12-106992072-G-C at positions 707-708.
# 140: Processed mutation chr12-106992081-T-C at positions 716-717.
# 141: Processed mutation chr12-106992088-T-C at positions 723-724.
# 142: Processed mutation chr12-106992089-A-G at positions 724-725.
# 143: Processed mutation chr12-106992100-ACTTATAGT-A at positions 735-744.
# 144: Processed mutation chr12-106992105-T-C at positions 740-741.
# 145: Processed mutation chr12-106992110-T-A at positions 745-746.
# 146: Processed mutation chr12-106992123-A-C at positions 758-759.
# 147: Processed mutation chr12-106992122-CAT-C at positions 757-760.
# 148: Processed mutation chr12-106992124-T-C at positions 759-760.
# 149: Processed mutation chr12-106992124-T-TA at positions 759-760.
# 150: Processed mutation chr12-106992138-A-G at positions 773-774.
# 151: Processed mutation chr12-106992148-G-C at positions 783-784.
# 152: Processed mutation chr12-106992151-AAC-A at positions 786-789.
# 153: Processed mutation chr12-106992154-A-G at positions 789-790.
# 154: Processed mutation chr12-106992158-T-C at positions 793-794.
# 155: Processed mutation chr12-106992167-GAAGA-G at positions 802-807.
# 156: Processed mutation chr12-106992174-C-A at positions 809-810.
# 157: Processed mutation chr12-106992179-A-C at positions 814-815.
# 158: Processed mutation chr12-106992181-T-A at positions 816-817.
# 159: Processed mutation chr12-106992193-G-A at positions 828-829.
# 160: Processed mutation chr12-106992195-C-A at positions 830-831.
# 161: Processed mutation chr12-106992199-T-A at positions 834-835.
# 162: Processed mutation chr12-106992200-C-T at positions 835-836.
# 163: Processed mutation chr12-106992204-C-T at positions 839-840.
# 164: Processed mutation chr12-106992205-G-A at positions 840-841.
# 165: Processed mutation chr12-106992209-A-C at positions 844-845.
# 166: Processed mutation chr12-106992210-A-C at positions 845-846.
# 167: Processed mutation chr12-106992223-T-C at positions 858-859.
# 168: Processed mutation chr12-106992231-A-T at positions 866-867.
# 169: Processed mutation chr12-106992234-C-A at positions 869-870.
# 170: Processed mutation chr12-106992236-C-A at positions 871-872.
# 171: Processed mutation chr12-106992239-A-G at positions 874-875.
# 506: Processed mutation chr12-106994262-C-T at positions 2897-2898.
# 507: Processed mutation chr12-106994267-T-C at positions 2902-2903.
# 508: Processed mutation chr12-106994280-G-A at positions 2915-2916.
# 509: Processed mutation chr12-106994281-G-A at positions 2916-2917.
# 510: Processed mutation chr12-106994289-T-C at positions 2924-2925.
# 511: Processed mutation chr12-106994312-C-T at positions 2947-2948.
# 512: Processed mutation chr12-106994313-C-T at positions 2948-2949.
# 513: Processed mutation chr12-106994332-G-A at positions 2967-2968.
# 514: Processed mutation chr12-106994345-A-G at positions 2980-2981.
# 515: Processed mutation chr12-106994360-C-T at positions 2995-2996.
# 516: Processed mutation chr12-106994374-T-C at positions 3009-3010.
# 517: Processed mutation chr12-106994377-T-A at positions 3012-3013.
# 518: Processed mutation chr12-106994380-C-T at positions 3015-3016.
# 519: Processed mutation chr12-106994398-C-T at positions 3033-3034.
# 520: Processed mutation chr12-106994409-A-G at positions 3044-3045.
# 521: Processed mutation chr12-106994436-T-C at positions 3071-3072.
# 522: Processed mutation chr12-106994439-G-A at positions 3074-3075.
# 523: Processed mutation chr12-106994454-C-CCA at positions 3089-3090.
# 524: Processed mutation chr12-106994456-A-C at positions 3091-3092.
# 525: Processed mutation chr12-106994457-C-A at positions 3092-3093.
# 526: Processed mutation chr12-106994458-A-T at positions 3093-3094.
# 527: Processed mutation chr12-106994467-T-C at positions 3102-3103.
# 528: Processed mutation chr12-106994476-G-C at positions 3111-3112.
# 529: Processed mutation chr12-106994479-C-T at positions 3114-3115.
# 530: Processed mutation chr12-106994488-T-C at positions 3123-3124.
# 531: Processed mutation chr12-106994494-T-A at positions 3129-3130.
# 532: Processed mutation chr12-106994497-C-T at positions 3132-3133.
# 533: Processed mutation chr12-106994498-T-TCATGTCTTTA at positions 3133-3134.
# 534: Processed mutation chr12-106994502-G-A at positions 3137-3138.
# 535: Processed mutation chr12-106994514-C-G at positions 3149-3150.
# 536: Processed mutation chr12-106994528-G-A at positions 3163-3164.
# 537: Processed mutation chr12-106994540-G-A at positions 3175-3176.
# 538: Processed mutation chr12-106994540-G-C at positions 3175-3176.
# 539: Processed mutation chr12-106994544-C-T at positions 3179-3180.
# 540: Processed mutation chr12-106994547-G-A at positions 3182-3183.
# 541: Processed mutation chr12-106994555-T-C at positions 3190-3191.
# 542: Processed mutation chr12-106994560-T-A at positions 3195-3196.
# 543: Processed mutation chr12-106994565-A-G at positions 3200-3201.
# 544: Processed mutation chr12-106994567-A-C at positions 3202-3203.
# 545: Processed mutation chr12-106994569-T-TG at positions 3204-3205.
# 546: Processed mutation chr12-106994578-GATTT-G at positions 3213-3218.
# 547: Processed mutation chr12-106994585-T-C at positions 3220-3221.
# 548: Processed mutation chr12-106994587-ATTC-A at positions 3222-3226.
# 549: Processed mutation chr12-106994591-T-C at positions 3226-3227.
# 550: Processed mutation chr12-106994593-CTATTA-C at positions 3228-3234.
# 551: Processed mutation chr12-106994608-C-G at positions 3243-3244.
# 552: Processed mutation chr12-106994610-A-G at positions 3245-3246.
# 553: Processed mutation chr12-106994612-C-G at positions 3247-3248.
# 554: Processed mutation chr12-106994616-T-C at positions 3251-3252.
# 555: Processed mutation chr12-106994618-T-C at positions 3253-3254.
# 556: Processed mutation chr12-106994622-T-C at positions 3257-3258.
# 557: Processed mutation chr12-106994630-G-A at positions 3265-3266.
# 558: Processed mutation chr12-106994636-T-C at positions 3271-3272.
# 559: Processed mutation chr12-106994646-T-C at positions 3281-3282.
# 560: Processed mutation chr12-106994650-C-T at positions 3285-3286.
# 561: Processed mutation chr12-106994653-G-A at positions 3288-3289.
# 562: Processed mutation chr12-106994654-C-T at positions 3289-3290.
# 563: Processed mutation chr12-106994656-A-G at positions 3291-3292.
# 564: Processed mutation chr12-106994657-C-G at positions 3292-3293.
# 565: Processed mutation chr12-106994657-CTA-C at positions 3292-3295.
# 566: Processed mutation chr12-106994661-G-A at positions 3296-3297.
# 567: Processed mutation chr12-106994662-A-T at positions 3297-3298.
# 568: Processed mutation chr12-106994672-G-A at positions 3307-3308.
# 569: Processed mutation chr12-106994673-A-T at positions 3308-3309.
# 570: Processed mutation chr12-106994673-A-G at positions 3308-3309.
# 571: Processed mutation chr12-106994687-T-C at positions 3322-3323.
# 572: Processed mutation chr12-106994691-C-T at positions 3326-3327.
# 573: Processed mutation chr12-106994692-G-A at positions 3327-3328.
# 574: Processed mutation chr12-106994695-A-G at positions 3330-3331.
# 575: Processed mutation chr12-106994699-G-T at positions 3334-3335.
# 576: Processed mutation chr12-106994700-T-C at positions 3335-3336.
# 577: Processed mutation chr12-106994705-G-A at positions 3340-3341.
# 578: Processed mutation chr12-106994719-A-G at positions 3354-3355.
# 579: Processed mutation chr12-106994721-T-A at positions 3356-3357.
# 580: Processed mutation chr12-106994727-C-T at positions 3362-3363.
# 581: Processed mutation chr12-106994732-A-G at positions 3367-3368.
# 582: Processed mutation chr12-106994738-T-C at positions 3373-3374.
# 583: Processed mutation chr12-106994742-A-AT at positions 3377-3378.
# 584: Processed mutation chr12-106994744-C-A at positions 3379-3380.
# 585: Processed mutation chr12-106994744-C-T at positions 3379-3380.
# 586: Processed mutation chr12-106994757-T-TC at positions 3392-3393.
# 587: Processed mutation chr12-106994760-T-C at positions 3395-3396.
# 588: Processed mutation chr12-106994767-T-C at positions 3402-3403.
# 589: Processed mutation chr12-106994770-C-A at positions 3405-3406.
# 590: Processed mutation chr12-106994788-A-G at positions 3423-3424.
# 591: Processed mutation chr12-106994791-G-T at positions 3426-3427.
# 592: Processed mutation chr12-106994807-G-A at positions 3442-3443.
# 593: Processed mutation chr12-106994809-C-T at positions 3444-3445.
# 594: Processed mutation chr12-106994810-C-T at positions 3445-3446.
# 595: Processed mutation chr12-106994819-T-C at positions 3454-3455.
# 596: Processed mutation chr12-106994821-T-G at positions 3456-3457.
# 597: Processed mutation chr12-106994823-T-A at positions 3458-3459.
# 598: Processed mutation chr12-106994823-T-C at positions 3458-3459.
# 599: Processed mutation chr12-106994826-G-T at positions 3461-3462.
# 600: Processed mutation chr12-106994830-A-G at positions 3465-3466.
# 601: Processed mutation chr12-106994840-C-A at positions 3475-3476.
# 602: Processed mutation chr12-106994842-G-A at positions 3477-3478.
# 603: Processed mutation chr12-106994847-C-T at positions 3482-3483.
# 604: Processed mutation chr12-106994851-A-G at positions 3486-3487.
# 605: Processed mutation chr12-106994855-G-A at positions 3490-3491.
# 606: Processed mutation chr12-106994874-G-C at positions 3509-3510.
# 607: Processed mutation chr12-106994884-T-C at positions 3519-3520.
# 608: Processed mutation chr12-106994888-G-C at positions 3523-3524.
# 609: Processed mutation chr12-106994901-CA-C at positions 3536-3538.
# 610: Processed mutation chr12-106994907-G-C at positions 3542-3543.
# 611: Processed mutation chr12-106994917-C-T at positions 3552-3553.
# 612: Processed mutation chr12-106994917-C-CT at positions 3552-3553.
# 613: Processed mutation chr12-106994930-T-C at positions 3565-3566.
# 614: Processed mutation chr12-106994955-G-A at positions 3590-3591.
# 615: Processed mutation chr12-106994960-T-C at positions 3595-3596.
# 616: Processed mutation chr12-106994963-C-T at positions 3598-3599.
# 617: Processed mutation chr12-106994966-C-T at positions 3601-3602.
# 618: Processed mutation chr12-106994969-C-T at positions 3604-3605.
# 619: Processed mutation chr12-106994981-C-T at positions 3616-3617.
# 620: Processed mutation chr12-106994999-T-C at positions 3634-3635.
# 621: Processed mutation chr12-106995004-T-C at positions 3639-3640.
# 622: Processed mutation chr12-106995014-A-T at positions 3649-3650.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9cc68761697a> in <cell line: 0>()
#       1 cry1_seq = get_CRY1_gene()
#       2 if cry1_seq:
# ----> 3     process_mutations(csv_file, cry1_seq, output_file)
#       4 else:
#       5     print("Failed to fetch CRY1 gene sequence.")
#
# <ipython-input-11-ebe556f101ab> in process_mutations(csv_path, cry1_seq, output_path)
#      33             if len(rows_save) >= batch:
#      34                 existing_data.extend(rows_save)
# ---> 35                 np.savez_compressed(output_path, arr_0=np.array(existing_data))
#      36                 rows_save = []
#      37
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in savez_compressed(file, *args, **kwds)
#     708
#     709     """
# --> 710     _savez(file, args, kwds, True)
#     711
#     712
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     741         # always force zip64, gh-10776
#     742         with zipf.open(fname, 'w', force_zip64=True) as fid:
# --> 743             format.write_array(fid, val,
#     744                                allow_pickle=allow_pickle,
#     745                                pickle_kwargs=pickle_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     733                     array, flags=['external_loop', 'buffered', 'zerosize_ok'],
#     734                     buffersize=buffersize, order='C'):
# --> 735                 fp.write(chunk.tobytes('C'))
#     736
#     737
#
# /usr/lib/python3.11/zipfile.py in write(self, data)
#    1176         self._crc = crc32(data, self._crc)
#    1177         if self._compressor:
# -> 1178             data = self._compressor.compress(data)
#    1179             self._compress_size += len(data)
#    1180         self._fileobj.write(data)
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU Memory Growth Enabled")
    except RuntimeError as e:
        print(e)
# Out:
# GPU Memory Growth Enabled
